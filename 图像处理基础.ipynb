# %%
import  numpy as  np
import  torch  as t
from  PIL  import Image 
import matplotlib.pyplot as plot

# %%
img=Image.open("/home/whf/111.png")
#type(img)
img.size
# Out:
# (1280, 1099)

# %%
sub1=plot.subplot(2,2,1)
sub1.plot([1,2,3,4],[5,7,8,9])
sub2=plot.subplot(2,2,2)
sub2.plot([1,2,3,4],[5,7,8,9])
sub3=plot.subplot(2,2,4)
sub3.plot([1,2,3,4],[5,7,8,9])
plot.show()

# %%
plot.imshow(img)
plot.show()

# %%
import matplotlib.pyplot as plt
fig = plt.figure()  # an empty figure with no axes
fig.suptitle('No axes on this figure')  # Add a title so we know which it is

fig, ax_lst = plt.subplots(2, 2)

# %%
ax_lst[0]
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f0b9ee96358>,
# ...
#       dtype=object)

# %%
#!pip install pandas
import pandas

# %%
a = pandas.DataFrame(np.random.rand(4,5), columns = list('abcde'))
a_asarray = a.values

# %%
b = np.matrix([[1,2],[3,4]])
b_asarray = np.asarray(b)

# %%
b_asarray
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
plot.imshow(b_asarray)

# %%
m=np.random.rand(512,512)
m
# Out:
# array([[0.63810683, 0.3076079 , 0.18302387, ..., 0.99245184, 0.75796193,
#         0.20190956],
#        [0.53173951, 0.85665723, 0.89356271, ..., 0.26646392, 0.27132137,
#         0.98996777],
#        [0.90191452, 0.90237729, 0.32881511, ..., 0.3533653 , 0.63128626,
#         0.8254027 ],
#        ...,
#        [0.96940756, 0.54459652, 0.1514939 , ..., 0.10795146, 0.2891384 ,
#         0.90664245],
#        [0.54330619, 0.26221889, 0.368875  , ..., 0.20149173, 0.55715414,
#         0.02958291],
#        [0.86477371, 0.52204721, 0.24872969, ..., 0.76667557, 0.50955389,
#         0.73731059]])

# %%
plt.imshow(m)

# %%
plt.imshow(m+10)

# %%
x = np.arange(0, 10, 0.2)
y = np.sin(x)
fig, ax = plt.subplots()
ax.plot(x, y)
plt.show()

# %%
x = np.arange(0, 10, 0.2)
y = np.sin(x)
fig, ax = plt.subplots()
dir={'x'}
#ax.plot(x, y,**dir)
plt.show()

# %%
#gray=plt.rgb2gray(im)
plt.imshow(img,cmap='gray')
plt.axis('off')
plt.show()

# %%
import cv2
img=cv2.imread("/home/whf/111.png")

# %%
plot.imshow(img)

# %%
img.shape , type(img)
# Out:
# ((1099, 1280, 3), numpy.ndarray)

# %%
img2=np.array([1099,1280,3])

img2[:][:][0]=img[:][:][2]
img2[:][:][1]=img[:][:][1]
img2[:][:][2]=img[:][:][0]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-3f5f30cce430> in <module>
#       1 img2=np.array([1099,1280,3])
#       2
# ----> 3 img2[:][:][0]=img[:][:][2]
#       4 img2[:][:][1]=img[:][:][1]
#       5 img2[:][:][2]=img[:][:][0]
#
# ValueError: setting an array element with a sequence.

# %%
img2[][]
# Out:
# array([1099, 1280,    3])

# %%
img[:][:][0].shape
# Out:
# (1280, 3)
