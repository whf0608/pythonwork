# %%
import numpy as np
from skimage import data
import matplotlib.pyplot  as plt
import cv2
from skimage import data, future, io

# %%
c=data.camera()
plt.imshow(c)

# %%
c.shape
# Out:
# (512, 512)

# %%
mask = future.manual_lasso_segmentation(c) 
plt.imshow(mask)

# %%
from skimage import feature
edges1 = feature.canny(c)
plt.imshow(edges1,'gray')

# %%
type(edges1),edges1.shape
# Out:
# (numpy.ndarray, (512, 512))

# %%
edges1
# Out:
# array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ...,  True, False, False],
#        [False, False, False, ...,  True, False, False],
#        [False, False, False, ..., False, False, False]])

# %%
descs, descs_img = feature.daisy(c, step=180, radius=58, rings=2, histograms=6,
                         orientations=8, visualize=True)

fig, ax = plt.subplots()
ax.axis('off')
ax.imshow(descs_img)
descs_num = descs.shape[0] * descs.shape[1]
ax.set_title('%i DAISY descriptors extracted:' % descs_num)
plt.show()
